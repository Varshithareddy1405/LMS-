# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
import PyPDF2
from PyPDF2 import PdfFileReader

# %%
pdf = open("file1pdf.pdf","rb")
pdf_reader = PyPDF2.PdfReader(pdf)
print("Number of pages:",len(pdf_reader.pages))
page = pdf_reader.pages[1]
print(page.extract_text())
pdf.close()
# Out:
# Number of pages: 35
#
#
#  Development  Plan for Greater Mumbai 2014‐2034
# Acknowledgements
# The Consultant  wishes to thank the following  individuals  from the Municipal  Corporation  of
# Greater Mumbai for their invaluable  support, insights and contributions  towards ‘Working  Paper 1
# – Preparation  of Base Map’ for the preparation  of the Development  Plan for Greater Mumbai
# 2014‐34.
#  Mr. Subodh Kumar, IAS, Municipal  Commissioner;
#  Mr. Rajeev Kuknoor, Chief Engineer Development  Plan;
#  Mr. Sudhir Ghate, Deputy Chief Engineer Development  Plan;
#  Mr. A.G. Marathe, Deputy Chief Engineer Development  Plan;
#  Mr. R. Balachandran,  Executive  Engineer and Town Planning Officer, Development  Plan.
#  Our gratitude  to the following  experts for their invaluable  insights and support:
# 
# Mr. V.K Phatak, Former Chief Town Planner (MMRDA);
#  Mr. A.N Kale, Former Chief Engineer, (DP);
#  Mr. A. S Jain Former Dy. Chief Engineer, (DP).
#  We wish to especially  thank MCGM officers, Mr. Jagdish Talreja, Mr. Dinesh Naik, Mr. Hiren
# Daftardar,  Ms. Anita Naik for their continual  support since the
#  beginning  of the project and their
# help towards familiarization  and data collection.  They have been instrumental  in helping to
# contact various MCGM departments  as well as in helping to establish contact with personnel  from
# other government  departments  and organizations.  Many thanks for the MCGM team, for
# deploying  personnel,  particularly  Mr. Prasad Gharat, on extensive  field visits that have helped in
# understanding  actual ground conditions.
#
# We apologize  if we have inadvertently  omitted anyone to whom acknowledgement  is due. We hope
# and anticipate  the work's usefulness  for the intended purpose.

# %%
import PyPDF2, urllib, nltk
from io import BytesIO
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
wFile = urllib.request.urlopen('http://www.udri.org/pdf/02%20working%20paper%201.pdf')
pdfreader = PyPDF2.PdfReader(BytesIO(wFile.read()))

# %%
pageObj = pdfreader.pages[2]
page2 = pageObj.extract_text()
punctuations = ['(',')',';',':','[',']',',','...','.']
tokens = word_tokenize(page2)
stop_words = stopwords.words('english')
keywords = [word for word in tokens if not word in stop_words and not word in punctuations]

# %%
keywords
# Out:
# ['Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '2014‐2034',
#  'Table',
#  'Contents',
#  'The',
#  'Consultant',
#  'wishes',
#  'thank',
#  'following',
#  'individuals',
#  'Municipal',
#  'Corporation',
#  'Greater',
#  'Mumbai',
#  'invaluable',
#  'support',
#  'insights',
#  'contributions',
#  'towards',
#  '‘',
#  'Working',
#  'Paper',
#  '1',
#  '–',
#  'Preparation',
#  'Base',
#  'Map',
#  '’',
#  'preparation',
#  'Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '2014‐34',
#  '.............................................................................................................................',
#  '..............',
#  '3',
#  'Our',
#  'gratitude',
#  'following',
#  'experts',
#  'invaluable',
#  'insights',
#  'support',
#  '............................',
#  '3',
#  'We',
#  'wish',
#  'especially',
#  'thank',
#  'MCGM',
#  'officers',
#  'Mr.',
#  'Jagdish',
#  'Talreja',
#  'Mr.',
#  'Dinesh',
#  'Naik',
#  'Mr.',
#  'Hiren',
#  'Daftardar',
#  'Ms.',
#  'Anita',
#  'Naik',
#  'continual',
#  'support',
#  'since',
#  'beginning',
#  'project',
#  'help',
#  'towards',
#  'familiarization',
#  'data',
#  'collection',
#  'They',
#  'instrumental',
#  'helping',
#  'contact',
#  'various',
#  'MCGM',
#  'departments',
#  'well',
#  'helping',
#  'establish',
#  'contact',
#  'personnel',
#  'government',
#  'departments',
#  'organizations',
#  'Many',
#  'thanks',
#  'MCGM',
#  'team',
#  'deploying',
#  'personnel',
#  'particularly',
#  'Mr.',
#  'Prasad',
#  'Gharat',
#  'extensive',
#  'field',
#  'visits',
#  'helped',
#  'understanding',
#  'actual',
#  'ground',
#  'conditions',
#  '........................................................................................',
#  '3',
#  'BEST',
#  '...............................................................................................................................',
#  '.................',
#  '5',
#  'Brihanmumbai',
#  'Electric',
#  'Supply',
#  'Transport',
#  'Undertaking',
#  '..............................................................',
#  '5',
#  'CIDCO',
#  '...............................................................................................................................',
#  '..............',
#  '5',
#  'City',
#  'Industrial',
#  'Development',
#  'Corporation',
#  '...............................................................................',
#  '5',
#  'CTP',
#  '...............................................................................................................................',
#  '..................',
#  '5',
#  'Comprehensive',
#  'Transportation',
#  'Plan',
#  '...............................................................................................',
#  '5',
#  'DP',
#  '...............................................................................................................................',
#  '....................',
#  '5',
#  'Development',
#  'Plan',
#  '..........................................................................................................................',
#  '5',
#  'DPGM34',
#  '...............................................................................................................................',
#  '..........',
#  '5',
#  'Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '2034',
#  '.......................................................................................',
#  '5',
#  'DCR',
#  '...............................................................................................................................',
#  '..................',
#  '5',
#  'Development',
#  'Control',
#  'Regulations',
#  '...................................................................................................',
#  '5',
#  'DGPS',
#  '...........................................................................................................................',
#  '....................',
#  '5',
#  'Digital',
#  'Global',
#  'Positioning',
#  'System',
#  '...................................................................................................',
#  '5',
#  'DPGM',
#  '...............................................................................................................................',
#  '..............',
#  '5',
#  'Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '...........................................................................................',
#  '5',
#  'ELU',
#  '...............................................................................................................................',
#  '..................',
#  '5',
#  'Existing',
#  'Land',
#  'use',
#  '.............................................................................................................................',
#  '5',
#  'FSI',
#  '...............................................................................................................................',
#  '....................',
#  '5',
#  'Floor',
#  'Space',
#  'Index',
#  '............................................................................................................................',
#  '5',
#  'GIS',
#  '...............................................................................................................................',
#  '...................',
#  '5']

# %%
name_list=list()
check=['Mr.','Mrs.', 'Ms.']
for idx, token in enumerate(tokens):
    if token.startswith(tuple(check)) and idx<(len(tokens)-1):
        name=token+tokens[idx+1] + ' ' +tokens[idx+2]
        name_list.append(name)
print(name_list)
# Out:
# ['Mr.Jagdish Talreja', 'Mr.Dinesh Naik', 'Mr.Hiren Daftardar', 'Ms.Anita Naik', 'Mr.Prasad Gharat']

# %%
# !pip install python-docx
# Out:
# Collecting python-docx
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\gunnala varshitha\anaconda3\lib\site-packages (from python-docx) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\gunnala varshitha\anaconda3\lib\site-packages (from python-docx) (4.11.0)
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
# Installing collected packages: python-docx
# Successfully installed python-docx-1.1.2

# %%
import docx

# %%
doc=open("file.docx","rb")
document=docx.Document(doc)

# %%
docu=""
for para in document.paragraphs:
    docu+=para.text
print(docu)
# Out:
# ATechnical Seminar OnARM BASED EMBEDDED WEB SERVERByKASALA AKHILA (21UP1A0420)DEPARTMENT OFELECTRONICS AND COMMUNICATION ENGINEERINGVIGNAN’S INSTITUTE OF MANAGEMENT AND TECHNOLOGY FOR WOMEN(An Autonomous Institution)(Approved by AICTE, New Delhi & Affiliated to JNTUH ,Hyderabad)Kondapur(V), Ghatkesar (M), Medchel-Malkajgiri(Dist), Telangana- 501301CONTENTSABSTRACTThis paper presents the design and implementation of an ARM-based embedded web server for Internet of Things (IoT) applications. The web server is built around an ARM Cortex-M microcontroller and runs a lightweight web server software, allowing it to provide web-based monitoring and control capabilities for IoT devices. The system features a compact and low-power design, making it suitable for battery-powered devices. The web server supports HTTP and HTTPS protocols, and provides features such as authentication, authorization, and data encryption. The system has been tested and validated on various IoT devices, demonstrating its feasibility and effectiveness. This work contributes to the development of efficient and secure web-based interfaces for IoT applications, enabling remote monitoring and control of devices and sensors.The proposed system leverages the strengths of ARM processors, including their compact form factor, low heat generation, and high integration potential. It supports key server functionalities such as data processing, communication protocols, and secure storage, making it ideal for distributed environments. Furthermore, its modular design ensures flexibility and scalability, enabling deployment in diverse scenarios like smart homes, industrial automation, and environmental monitoring.The study highlights the embedded server's ability to handle real-time data streams, optimize power consumption, and maintain robust performance under varying workloads. Experimental results demonstrate its effectiveness in reducing energy costs and improving response times compared to traditional server architectures. This work underscores the potential of ARM-based embedded servers as a cornerstone of future energy-efficient, decentralized computing infrastructures.The growing demand for efficient, scalable, and low-power computing solutions has led to increased interest in ARM-based embedded systems for server applications. ARM processors, known for their energy efficiency and high performance per watt, are well-suited for a wide range of embedded server tasks, from IoT device management to edge computing. This paper presents the design and implementation of an ARM-based embedded server, focusing on its architecture, capabilities, and applications.iiiPREFACEIn today's interconnected world, the demand for efficient, compact, and energy-conscious computing systems is greater than ever. Traditional server architectures, while powerful, often face limitations in scalability, energy efficiency, and adaptability to diverse deployment environments. This has led to a paradigm shift toward lightweight, versatile solutions capable of meeting the needs of modern applications, particularly in edge computing and Internet of Things (IoT) domains.ARM-based embedded servers emerge as a promising solution in this context, offering a unique combination of performance, low power consumption, and compact design. Their ability to integrate seamlessly into decentralized systems makes them ideal for applications ranging from smart homes and industrial automation to real-time environmental monitoring.This work delves into the design, capabilities, and potential of ARM-based embedded servers, aiming to bridge the gap between traditional computing infrastructures and the evolving requirements of energy-efficient, distributed systems. By exploring the possibilities of ARM technology in server design, we hope to provide valuable insights for researchers, engineers, and technology enthusiasts interested in building the next generation of innovative computing solutions.ivLIST OF FIGURESv

# %%
for i in range(len(document.paragraphs)):
    print("The content of the paragraph"+str(i)+" is : "+document.paragraphs[i].text+"\n")
# Out:
# The content of the paragraph0 is : A
#
# The content of the paragraph1 is : Technical Seminar On
#
# The content of the paragraph2 is : ARM BASED EMBEDDED WEB SERVER
#
# The content of the paragraph3 is : By
#
# The content of the paragraph4 is : KASALA AKHILA
#
# The content of the paragraph5 is : (21UP1A0420)
#
# The content of the paragraph6 is :
#
# The content of the paragraph7 is :
#
# The content of the paragraph8 is :
#
# The content of the paragraph9 is :
#
# The content of the paragraph10 is :
#
# The content of the paragraph11 is :
#
# The content of the paragraph12 is :
#
# The content of the paragraph13 is : DEPARTMENT OF
#
# The content of the paragraph14 is : ELECTRONICS AND COMMUNICATION ENGINEERING
#
# The content of the paragraph15 is :
#
# The content of the paragraph16 is : VIGNAN’S INSTITUTE OF MANAGEMENT AND TECHNOLOGY FOR WOMEN
#
# The content of the paragraph17 is : (An Autonomous Institution)
#
# The content of the paragraph18 is : (Approved by AICTE, New Delhi & Affiliated to JNTUH ,Hyderabad)
#
# The content of the paragraph19 is : Kondapur(V), Ghatkesar (M), Medchel-Malkajgiri(Dist), Telangana- 501301
#
# The content of the paragraph20 is :
#
# The content of the paragraph21 is : CONTENTS
#
# The content of the paragraph22 is :
#
# The content of the paragraph23 is : ABSTRACT
#
# The content of the paragraph24 is :
#
# The content of the paragraph25 is : This paper presents the design and implementation of an ARM-based embedded web server for Internet of Things (IoT) applications. The web server is built around an ARM Cortex-M microcontroller and runs a lightweight web server software, allowing it to provide web-based monitoring and control capabilities for IoT devices.
#
# The content of the paragraph26 is :
#
# The content of the paragraph27 is :  The system features a compact and low-power design, making it suitable for battery-powered devices. The web server supports HTTP and HTTPS protocols, and provides features such as authentication, authorization, and data encryption. The system has been tested and validated on various IoT devices, demonstrating its feasibility and effectiveness.
#
# The content of the paragraph28 is :
#
# The content of the paragraph29 is : This work contributes to the development of efficient and secure web-based interfaces for IoT applications, enabling remote monitoring and control of devices and sensors.
#
# The content of the paragraph30 is :
#
# The content of the paragraph31 is : The proposed system leverages the strengths of ARM processors, including their compact form factor, low heat generation, and high integration potential. It supports key server functionalities such as data processing, communication protocols, and secure storage, making it ideal for distributed environments.
#
# The content of the paragraph32 is :
#
# The content of the paragraph33 is : Furthermore, its modular design ensures flexibility and scalability, enabling deployment in diverse scenarios like smart homes, industrial automation, and environmental monitoring.
#
# The content of the paragraph34 is :
#
# The content of the paragraph35 is : The study highlights the embedded server's ability to handle real-time data streams, optimize power consumption, and maintain robust performance under varying workloads. Experimental results demonstrate its effectiveness in reducing energy costs and improving response times compared to traditional server architectures.
#
# The content of the paragraph36 is :
#
# The content of the paragraph37 is : This work underscores the potential of ARM-based embedded servers as a cornerstone of future energy-efficient, decentralized computing infrastructures.
#
# The content of the paragraph38 is :
#
# The content of the paragraph39 is : The growing demand for efficient, scalable, and low-power computing solutions has led to increased interest in ARM-based embedded systems for server applications. ARM processors, known for their energy efficiency and high performance per watt, are well-suited for a wide range of embedded server tasks, from IoT device management to edge computing.
#
# The content of the paragraph40 is :
#
# The content of the paragraph41 is :  This paper presents the design and implementation of an ARM-based embedded server, focusing on its architecture, capabilities, and applications.
#
# The content of the paragraph42 is :
#
# The content of the paragraph43 is :
#
# The content of the paragraph44 is :
#
# The content of the paragraph45 is :
#
# The content of the paragraph46 is :
#
# The content of the paragraph47 is :
#
# The content of the paragraph48 is :
#
# The content of the paragraph49 is :
#
# The content of the paragraph50 is :
#
# The content of the paragraph51 is :
#
# The content of the paragraph52 is :
#
# The content of the paragraph53 is :
#
# The content of the paragraph54 is :
#
# The content of the paragraph55 is :
#
# The content of the paragraph56 is : iii
#
# The content of the paragraph57 is :
#
# The content of the paragraph58 is : PREFACE
#
# The content of the paragraph59 is :
#
# The content of the paragraph60 is : In today's interconnected world, the demand for efficient, compact, and energy-conscious computing systems is greater than ever. Traditional server architectures, while powerful, often face limitations in scalability, energy efficiency, and adaptability to diverse deployment environments. This has led to a paradigm shift toward lightweight, versatile solutions capable of meeting the needs of modern applications, particularly in edge computing and Internet of Things (IoT) domains.
#
# The content of the paragraph61 is :
#
# The content of the paragraph62 is :
#
# The content of the paragraph63 is : ARM-based embedded servers emerge as a promising solution in this context, offering a unique combination of performance, low power consumption, and compact design. Their ability to integrate seamlessly into decentralized systems makes them ideal for applications ranging from smart homes and industrial automation to real-time environmental monitoring.
#
# The content of the paragraph64 is :
#
# The content of the paragraph65 is :
#
# The content of the paragraph66 is : This work delves into the design, capabilities, and potential of ARM-based embedded servers, aiming to bridge the gap between traditional computing infrastructures and the evolving requirements of energy-efficient, distributed systems. By exploring the possibilities of ARM technology in server design, we hope to provide valuable insights for researchers, engineers, and technology enthusiasts interested in building the next generation of innovative computing solutions.
#
# The content of the paragraph67 is :
#
# The content of the paragraph68 is :
#
# The content of the paragraph69 is :
#
# The content of the paragraph70 is :
#
# The content of the paragraph71 is :
#
# The content of the paragraph72 is :
#
# The content of the paragraph73 is :
#
# The content of the paragraph74 is :
#
# The content of the paragraph75 is :
#
# The content of the paragraph76 is :
#
# The content of the paragraph77 is :
#
# The content of the paragraph78 is :
#
# The content of the paragraph79 is :
#
# The content of the paragraph80 is :
#
# The content of the paragraph81 is :
#
# The content of the paragraph82 is :
#
# The content of the paragraph83 is :
#
# The content of the paragraph84 is :
#
# The content of the paragraph85 is :
#
# The content of the paragraph86 is :
#
# The content of the paragraph87 is :
#
# The content of the paragraph88 is :
#
# The content of the paragraph89 is :
#
# The content of the paragraph90 is :
#
# The content of the paragraph91 is :
#
# The content of the paragraph92 is :
#
# The content of the paragraph93 is :
#
# The content of the paragraph94 is :
#
# The content of the paragraph95 is :
#
# The content of the paragraph96 is : iv
#
# The content of the paragraph97 is :
#
# The content of the paragraph98 is : LIST OF FIGURES
#
# The content of the paragraph99 is :
#
# The content of the paragraph100 is :
#
# The content of the paragraph101 is :
#
# The content of the paragraph102 is :
#
# The content of the paragraph103 is :
#
# The content of the paragraph104 is :
#
# The content of the paragraph105 is :
#
# The content of the paragraph106 is :
#
# The content of the paragraph107 is :
#
# The content of the paragraph108 is :
#
# The content of the paragraph109 is :
#
# The content of the paragraph110 is :
#
# The content of the paragraph111 is :
#
# The content of the paragraph112 is : v

# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in c:\users\gunnala varshitha\anaconda3\lib\site-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\gunnala varshitha\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.5)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
import urllib.request as urllib2
from bs4 import BeautifulSoup

# %%
response=urllib2.urlopen('https://en.wikipedia.org/wiki/Natural_language_processing')
html_doc=response.read()

# %%
soup=BeautifulSoup(html_doc,'html.parser')
strhtm=soup.prettify()
